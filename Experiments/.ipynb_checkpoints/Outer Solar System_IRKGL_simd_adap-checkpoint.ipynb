# %% [markdown]
# # Outer Solar System IRKGL-simd-adap

# %% [markdown]
# ## Loading packages and functions

# %%
using LinearAlgebra
using Plots
using IRKGaussLegendre
using OrdinaryDiffEq
#using BenchmarkTools

# %%
PATH_SRC="../src/"

include(string(PATH_SRC,"IRKGL_SIMD_adap.jl"))
using .IRKGL_SIMD_adap

# %%
PATH_SRC="../src1/"

include(string(PATH_SRC,"IRKGL_SIMD.jl"))
using .IRKGL_SIMD

# %% [markdown]
# ## Definition of the N-body problem
#
# In Nbody.jl below, the following functions are defined: NbodyEnergy(u,Gm), NbodyODE!(du,u,Gm,t), and NbodyODE1!(du,u,Gm,t), where
#
# \begin{equation*}
# u =
# \left(\begin{matrix}
# q_1  & v_1\\
# \vdots & \vdots \\
# q_N  & v_N
# \end{matrix}
# \right) \in \mathbb{R}^{2 \times 3\times N}, \quad
# Gm = (G\,  m_1, \ldots,G\,  m_N) \in \mathbb{R}^N.
# \end{equation*}

# %% [markdown]
# The energy, as a function of the positions $q_1,\ldots,q_N \in \mathbb{R}^3$ and the velocities $v_1,\ldots,v_N \in \mathbb{R}^3$ of the $N$ bodies is:
# \begin{equation*}
# \begin{split}
# \mathrm{Energy}(q_1,\ldots,q_N,v_1,\ldots,v_N) =
# \frac12 \sum_{i=1}^{N} m_i \, \|v_i\|^2
# - G \sum_{1\leq i < j \leq N} \frac{m_i m_j}{\|q_i-q_j\|}.
# \end{split}
# \end{equation*}
#
#
# The ODE system of the N-body problem,
# as a function of the positions $q_1,\ldots,q_N \in \mathbb{R}^3$ and the velocities $v_1,\ldots,v_N \in \mathbb{R}^3$ of the $N$ bodies is:
# \begin{equation*}
# \begin{split}
# \frac{d}{dt} q_i &= v_i, \\
# \frac{d}{dt} v_i &= G\,
# \sum_{j \neq i} \frac{m_j}{\|q_j-q_i\|^3}\,
# (q_j-q_i).
# \end{split}
# \end{equation*}
# This system of ODEs can be writen in compact form as
# \begin{equation*}
# \frac{d u}{dt} = f(t,u,Gm)
# \end{equation*}

# %%
PATH_ODES="../ODEProblems/"

include(string(PATH_ODES,"Initial5Body.jl"))
include(string(PATH_ODES,"Nbody.jl"))
include(string(PATH_ODES,"Nbody2nd.jl"))
# Out:
# NbodyODE2nd! (generic function with 1 method)

# %% [markdown]
# ##### <a href="#top">Back to the top</a>
#
# ## Initial value problem: 5-body problem (outer solar system)
#
# We consider $N=5$ bodies of the outer solar system: the Sun, Jupiter, Saturn, Uranus, and Neptune.
# The initial values $u_{00}$ are taken from DE430, Julian day (TDB) 2440400.5 (June 28, 1969).

# %%
u0, Gm, bodylist = Initial5Body(Float64)
q0=u0[:,:,1]
v0=u0[:,:,2]
dim=length(size(u0))

N = length(Gm)

show(bodylist)
E0=NbodyEnergy(u0,Gm)
# Out:
# ["Sun" "Jupiter" "Saturn" "Uranus" "Neptune"]
# -9.522696242724852e-12

# %% [markdown]
# ### IRKGL_simd eta IRKGL16 integrazioak

# %%
t0 = 0.
dt = 500.
tF = 1e4  #1e8
tF=  1e6
tF = 3*dt

#n = 100
#n = 5

#m = convert(Int64,ceil(abs(tF-t0)/(n*dt)))
#n = convert(Int64,ceil(abs(tF-t0)/(m*dt))) # Number of macro-steps (Output is saved for n+1 time values)
#dt = (tF-t0)/(n*m)

m=1
println("dt = $dt, m=$m")

prob = ODEProblem(NbodyODE!, u0, (t0,tF), Gm)

tol=1e-6

alg=IRKGL_simd_adap(s=8,partitioned=false, initial_interp=0,dim=3,floatType=Float64, m=m,myoutputs=true)
sol1,iters1=solve(prob,alg,dt=dt,adaptive=true); 

#alg=IRKGL_simd(s=8,partitioned=false, initial_interp=0,dim=3,floatType=Float64, m=m,myoutputs=true)
#sol2,iters2=solve(prob,alg,dt=dt, adaptive=false); 

#sol3=solve(prob, IRKGL16(), dt=dt,  adaptive=false);
# Out:
# dt = 500.0, m=1
# urratsa berria------- j=1,dt=500.0
# iterazioa ** j_iter=0,dt=500.0Plusit=true
# iterazioa ** j_iter=1,dt=500.0Plusit=true
# iterazioa ** j_iter=2,dt=500.0Plusit=true
# iterazioa ** j_iter=3,dt=500.0Plusit=true
# iterazioa ** j_iter=4,dt=500.0Plusit=true
# iterazioa ** j_iter=5,dt=500.0Plusit=true
# iterazioa ** j_iter=6,dt=500.0Plusit=true
# iterazioa ** j_iter=7,dt=500.0Plusit=true
# iterazioa ** j_iter=8,dt=500.0Plusit=true
# iterazioa ** j_iter=9,dt=500.0Plusit=true
# iterazioa ** j_iter=10,dt=500.0Plusit=true
# iterazioa ** j_iter=11,dt=500.0Plusit=true
# iterazioa ** j_iter=12,dt=500.0Plusit=true
# iterazioa ** j_iter=13,dt=500.0Plusit=true
# iterazioa ** j_iter=14,dt=500.0Plusit=true
# iterazioa ** j_iter=15,dt=500.0Plusit=true
# iterazioa ** j_iter=16,dt=500.0Plusit=true
# iterazioa ** j_iter=17,dt=500.0Plusit=true
# iterazioa ** j_iter=18,dt=500.0Plusit=true
# iterazioa ** j_iter=19,dt=500.0Plusit=true
# iterazioa ** j_iter=20,dt=500.0Plusit=true
# iterazioa ** j_iter=21,dt=500.0Plusit=true
# iterazioa ** j_iter=22,dt=500.0Plusit=false
# iterazioa ** j_iter=23,dt=500.0Plusit=true
# iterazioa ** j_iter=24,dt=500.0Plusit=true
# iterazioa ** j_iter=25,dt=500.0Plusit=true
# iterazioa ** j_iter=26,dt=500.0Plusit=true
# iterazioa ** j_iter=27,dt=500.0Plusit=true
# iterazioa ** j_iter=28,dt=500.0Plusit=false
# iterazioa ** j_iter=29,dt=500.0Plusit=true
# iterazioa ** j_iter=30,dt=500.0Plusit=true
# iterazioa ** j_iter=31,dt=500.0Plusit=false
# iterazioa ** j_iter=32,dt=500.0Plusit=true
# iterazioa ** j_iter=33,dt=500.0Plusit=false
# urratsa berria------- j=2,dt=500.0
# iterazioa ** j_iter=0,dt=500.0Plusit=true
# iterazioa ** j_iter=1,dt=496.8125Plusit=true
# iterazioa ** j_iter=2,dt=303.375Plusit=true
# iterazioa ** j_iter=3,dt=234.84375Plusit=true
# iterazioa ** j_iter=4,dt=296.875Plusit=true
# iterazioa ** j_iter=5,dt=347.75Plusit=true
# iterazioa ** j_iter=6,dt=350.3125Plusit=true
# iterazioa ** j_iter=7,dt=469.5Plusit=false
# urratsa berria------- j=3,dt=488.6875
# iterazioa ** j_iter=0,dt=488.6875Plusit=true
# iterazioa ** j_iter=1,dt=447.8125Plusit=true
# iterazioa ** j_iter=2,dt=294.125Plusit=true
# iterazioa ** j_iter=3,dt=224.125Plusit=true
# iterazioa ** j_iter=4,dt=275.6875Plusit=true
# iterazioa ** j_iter=5,dt=320.4375Plusit=true
# iterazioa ** j_iter=6,dt=328.375Plusit=true
# iterazioa ** j_iter=7,dt=430.625Plusit=false
# iterazioa ** j_iter=8,dt=432.375Plusit=true
# iterazioa ** j_iter=9,dt=413.625Plusit=false
# iterazioa ** j_iter=10,dt=412.75Plusit=true
# iterazioa ** j_iter=11,dt=411.875Plusit=true
# iterazioa ** j_iter=12,dt=411.875Plusit=true
# iterazioa ** j_iter=13,dt=411.8125Plusit=false
# urratsa berria------- j=4,dt=99.4375
# iterazioa ** j_iter=0,dt=99.4375Plusit=true
# iterazioa ** j_iter=1,dt=99.4375Plusit=true
# iterazioa ** j_iter=2,dt=99.4375Plusit=true
# iterazioa ** j_iter=3,dt=99.4375Plusit=true
# iterazioa ** j_iter=4,dt=99.4375Plusit=true
# iterazioa ** j_iter=5,dt=99.4375Plusit=true
# iterazioa ** j_iter=6,dt=99.4375Plusit=true
# iterazioa ** j_iter=7,dt=99.4375Plusit=true
# iterazioa ** j_iter=8,dt=99.4375Plusit=true
# iterazioa ** j_iter=9,dt=99.4375Plusit=true
# iterazioa ** j_iter=10,dt=99.4375Plusit=true
# iterazioa ** j_iter=11,dt=99.4375Plusit=true
# iterazioa ** j_iter=12,dt=99.4375Plusit=true
# iterazioa ** j_iter=13,dt=99.4375Plusit=true
# iterazioa ** j_iter=14,dt=99.4375Plusit=true
# iterazioa ** j_iter=15,dt=99.4375Plusit=true
# iterazioa ** j_iter=16,dt=99.4375Plusit=true
# iterazioa ** j_iter=17,dt=99.4375Plusit=true
# iterazioa ** j_iter=18,dt=99.4375Plusit=false
# iterazioa ** j_iter=19,dt=99.4375Plusit=true
# iterazioa ** j_iter=20,dt=99.4375Plusit=false
# iterazioa ** j_iter=21,dt=99.4375Plusit=true
# iterazioa ** j_iter=22,dt=99.4375Plusit=true
# iterazioa ** j_iter=23,dt=99.4375Plusit=false

# %%
#alg=IRKGL_simd(s=8,partitioned=false, initial_interp=0,dim=3,floatType=Float64, m=m,myoutputs=true)
#sol2,iters2=solve(prob,alg,dt=dt, adaptive=false); 

sol3=solve(prob, IRKGL16(), dt=dt,  adaptive=true);

# %%
sol1.t
# Out:
# 5-element Vector{Float64}:
#     0.0
#   500.0
#   988.6875
#  1400.5625
#  1500.0

# %%
sol3.t
# Out:
# 3-element Vector{Float64}:
#     0.0
#   500.0
#  1500.0

# %%
tt=sol1.t
plot(title="Urrats luzerak")
plot!(tt[2:end],tt[2:end]-tt[1:end-1], label="IRKGL_simd_berria")
#tt2=sol2.t
#plot!(tt2[2:end],tt2[2:end]-tt2[1:end-1], label="IRKGL_simd")
tt3=sol3.t
plot!(tt3[2:end],tt3[2:end]-tt3[1:end-1], label="IRKGL16")

# %%
plot(title="Iterazioak")
plot!(tt,iters1,label="IRKGL_simd_berria")
#plot!(tt,iters2,label="IRKGL_simd")

# %%
yrange = (1e-16,1e-4)
year = 365.5

function energy_plot(sol; title="")
    energies = [NbodyEnergy(BigFloat.(u),Gm) for u in sol.u]
    E0 = energies[1]
    epsilon = eps(1e-3)
    errors = Float64.(abs.(energies[2:end]/E0 .- 1)) .+ epsilon
    tt = sol.t[2:end]  #/year
    pl = plot(title=title,
         yscale=:log10, legend=false) #ylims=yrange, 
    plot!(tt,  errors)
    return pl
end


pl1 = energy_plot(sol1, title="IRKGL_simd_berria")

#pl2 = energy_plot(sol2, title="IRKGL_simd")

pl3 = energy_plot(sol3, title="IRKGL16 ")


plot(pl1, pl3,  layout=(2,1), size=(600,450))
