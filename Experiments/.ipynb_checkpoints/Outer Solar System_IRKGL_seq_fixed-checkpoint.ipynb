# %% [markdown]
# # Outer Solar System IRKGL-simd-fixed

# %% [markdown]
# ## Loading packages and functions

# %%
using LinearAlgebra
using Plots
using IRKGaussLegendre
using OrdinaryDiffEq
#using BenchmarkTools

# %%
PATH_SRC="../src_seq2/"

include(string(PATH_SRC,"IRKGL_SEQ2.jl"))
using .IRKGL_SEQ2

# %%
PATH_SRC="../src_seq1/"

include(string(PATH_SRC,"IRKGL_SEQ.jl"))
using .IRKGL_SEQ1

# %% [markdown]
# ## Definition of the N-body problem
#
# In Nbody.jl below, the following functions are defined: NbodyEnergy(u,Gm), NbodyODE!(du,u,Gm,t), and NbodyODE1!(du,u,Gm,t), where
#
# \begin{equation*}
# u =
# \left(\begin{matrix}
# q_1  & v_1\\
# \vdots & \vdots \\
# q_N  & v_N
# \end{matrix}
# \right) \in \mathbb{R}^{2 \times 3\times N}, \quad
# Gm = (G\,  m_1, \ldots,G\,  m_N) \in \mathbb{R}^N.
# \end{equation*}

# %% [markdown]
# The energy, as a function of the positions $q_1,\ldots,q_N \in \mathbb{R}^3$ and the velocities $v_1,\ldots,v_N \in \mathbb{R}^3$ of the $N$ bodies is:
# \begin{equation*}
# \begin{split}
# \mathrm{Energy}(q_1,\ldots,q_N,v_1,\ldots,v_N) =
# \frac12 \sum_{i=1}^{N} m_i \, \|v_i\|^2
# - G \sum_{1\leq i < j \leq N} \frac{m_i m_j}{\|q_i-q_j\|}.
# \end{split}
# \end{equation*}
#
#
# The ODE system of the N-body problem,
# as a function of the positions $q_1,\ldots,q_N \in \mathbb{R}^3$ and the velocities $v_1,\ldots,v_N \in \mathbb{R}^3$ of the $N$ bodies is:
# \begin{equation*}
# \begin{split}
# \frac{d}{dt} q_i &= v_i, \\
# \frac{d}{dt} v_i &= G\,
# \sum_{j \neq i} \frac{m_j}{\|q_j-q_i\|^3}\,
# (q_j-q_i).
# \end{split}
# \end{equation*}
# This system of ODEs can be writen in compact form as
# \begin{equation*}
# \frac{d u}{dt} = f(t,u,Gm)
# \end{equation*}

# %%
PATH_ODES="../ODEProblems/"

include(string(PATH_ODES,"Initial5Body.jl"))
include(string(PATH_ODES,"Nbody.jl"))
include(string(PATH_ODES,"Nbody2nd.jl"))
# Out:
# NbodyODE2nd! (generic function with 1 method)

# %% [markdown]
# ##### <a href="#top">Back to the top</a>
#
# ## Initial value problem: 5-body problem (outer solar system)
#
# We consider $N=5$ bodies of the outer solar system: the Sun, Jupiter, Saturn, Uranus, and Neptune.
# The initial values $u_{00}$ are taken from DE430, Julian day (TDB) 2440400.5 (June 28, 1969).

# %%
u0, Gm, bodylist = Initial5Body(Float64)
q0=u0[:,:,1]
v0=u0[:,:,2]
dim=length(size(u0))

N = length(Gm)

show(bodylist)
E0=NbodyEnergy(u0,Gm)
# Out:
# ["Sun" "Jupiter" "Saturn" "Uranus" "Neptune"]
# -9.522696242724852e-12

# %% [markdown]
# ### IRKGL_simd eta IRKGL16 integrazioak

# %%
t0 = 0.
dt = 500.  # 500.
tF = 1e4  #1e8
tF=  1e6
tF = 10*dt

#n = 100
#n = 5

#m = convert(Int64,ceil(abs(tF-t0)/(n*dt)))
#n = convert(Int64,ceil(abs(tF-t0)/(m*dt))) # Number of macro-steps (Output is saved for n+1 time values)
#dt = (tF-t0)/(n*m)

m=1
println("dt = $dt, m=$m")

prob = ODEProblem(NbodyODE!, u0, (t0,tF), Gm)

tol=1e-6

# Formulazio berria
alg=IRKGL_Seq2(s=8,partitioned=false, initial_interp=0, m=m,myoutputs=true)
sol1,iters1=solve(prob,alg,dt=dt, adaptive=false); 

algh2=IRKGL_Seq2(s=8,partitioned=false, initial_interp=0, m=2*m,myoutputs=true)
sol1h2,iters1h2=solve(prob,algh2,dt=dt/2, adaptive=false); 

algh4=IRKGL_Seq2(s=8,partitioned=false, initial_interp=0, m=4*m,myoutputs=true)
sol1h4,iters1h4=solve(prob,algh4,dt=dt/4, adaptive=false); 

# Mu formulazioa (bektorizatutako bertsioa)
alg=IRKGL_Seq1(s=8,partitioned=false, initial_interp=0, m=m,myoutputs=true)
sol2,iters2=solve(prob,alg,dt=dt, adaptive=false); 

# IRKGL16 (SCML bertsioa)
sol3=solve(prob, IRKGL16(), dt=dt,  adaptive=false);
# Out:
# dt = 500.0, m=1

# %%
#tt=sol1.t
#plot(title="Urrats luzerak")
#plot!(tt[2:end],tt[2:end]-tt[1:end-1], label="IRKGL_simd_berria")
#tt2=sol2.t
#plot!(tt2[2:end],tt2[2:end]-tt2[1:end-1], label="IRKGL_simd")
#tt3=sol3.t
#plot!(tt3[2:end],tt3[2:end]-tt3[1:end-1], label="IRKGL16")

# %%
tt=sol1.t
plot(title="Iterazioak")
plot!(tt,iters1,label="IRKGL_Seq_berria")
plot!(tt,iters1h2,label="IRKGL_Seq_berria h/2")
plot!(tt,iters1h4,label="IRKGL_Seq_berria h/4")
plot!(tt,iters2,label="IRKGL_Seq")

# %% [markdown]
# ### Energy erroreak

# %%
yrange = (1e-16,1e-4)
year = 365.5

function energy_plot(sol; title="")
    energies = [NbodyEnergy(BigFloat.(u),Gm) for u in sol.u]
    E0 = energies[1]
    epsilon = eps(1e-3)
    errors = Float64.(abs.(energies[2:end]/E0 .- 1)) .+ epsilon
    tt = sol.t[2:end]  #/year
    pl = plot(title=title,
         yscale=:log10, legend=false) #ylims=yrange, 
    plot!(tt,  errors)
    return pl
end
# Out:
# energy_plot (generic function with 1 method)

# %%
pl1 = energy_plot(sol1, title="IRKGL_simd_berria")

pl1h2 = energy_plot(sol1h2, title="IRKGL_simd berria h/2")

pl1h4 = energy_plot(sol1h4, title="IRKGL_simd berria h/4")

pl2 = energy_plot(sol2, title="IRKGL_simd")

pl3 = energy_plot(sol3, title="IRKGL16 ")


plot(pl1, pl1h2, pl1h4, pl2,   layout=(2,2), size=(800,500))

# %% [markdown]
# ### Kokapenen diferentziak
#
# u[a,b,c]
#
#    -a:  =1:3  x,y,z;
#    -b:  =1:5  gorputa
#    -c:  =1 kokapenak;   =2 abiadura

# %%
norm(sol1.u[1]-sol2.u[1])
# Out:
# 0.0

# %%
qq1=[u[:,:,1] for u in sol1.u]
qq1h2=[u[:,:,1] for u in sol1h2.u]
qq1h4=[u[:,:,1] for u in sol1h4.u]
qq2=[u[:,:,1] for u in sol2.u]

plot(sol1.t,norm.((qq1-qq2)),seriestype=:scatter, label="qq1-qq2")
#plot!(sol1.t,norm.((qq1-qq1h2)),seriestype=:scatter, label="qq1-qq2h2")
#plot!(sol1.t,norm.((qq1-qq1h4)), seriestype=:scatter, label="qq1-qq2h4")

# %%
norm.((qq1-qq2))./norm.((qq1-qq1h2))
# Out:
# 11-element Vector{Float64}:
#  NaN
#    1.306085317952146
#    0.9837613524443919
#    1.1100734896111915
#    1.201973898253808
#    1.4101888527334503
#    1.4909455852550593
#    1.509128919336683
#    1.5244557419984668
#    1.5467085530271176
#    1.5423155050597501

# %%
norm.((qq1-qq2))./norm.((qq1-qq1h4))
# Out:
# 11-element Vector{Float64}:
#  NaN
#    1.0563339031938876
#    1.2808661458723465
#    1.4588851792320014
#    1.2602704987302376
#    1.257222853160696
#    1.3167383852423844
#    1.3823149115735587
#    1.4278818627872212
#    1.448929839027336
#    1.4284871825562002

# %%
b,c,mu,nu,nu1,nu2,gamma=IRKGL_SIMD_adap.IRKGLCoefficients_adap(8,dt);
# Out:
# UndefVarError: IRKGL_SIMD_adap not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[15]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
norm(gamma)*norm(inv(gamma))
# Out:
# UndefVarError: gamma not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[16]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
gamma*inv(gamma)
# Out:
# UndefVarError: gamma not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[17]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116
