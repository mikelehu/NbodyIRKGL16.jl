# %%
using Plots

# %% [markdown]
# ## Legends1

# %%
x = 1:10; y = rand(10); # These are the plotting data
plot(title="legends", legend=:outerbottom)
plot!(x, y, seriestype=:scatter, color="blue", label="IRKGL16_seq")
plot!(x, y, seriestype=:scatter, color="green", label="IRKGL16_simd")

# %% [markdown]
# ## Legends2

# %%
x = 1:10; y = rand(10); # These are the plotting data
plot(title="legends", legend=:outerbottom)
plot!(x, y, seriestype=:scatter, color="green", label="IRKGL16_simd")
plot!(x, y, seriestype=:scatter, color="orange", label="Vern9")
plot!(x, y, seriestype=:scatter, color="gray", label="DPRKN12")
